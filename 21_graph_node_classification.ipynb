# %%
# GNN: Graph Neural Network
# 画像に対するCNNの一般化みたいなノリでグラフに畳み込み演算をしてみるみたいな話
# Coraという論文の引用グラフを利用．頂点が論文，辺が引用関係
# 頂点ごとにbag-of-wordsで特徴ベクトルを作って，引用関係に基づいて畳み込み
# 最終的に各頂点の分野を予測して頂点を分類するタスク

# %%
import os 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import networkx as nx

# %%
# prepare dataset
# - #nodes 2708
# - #classes 7
# - #edges 5429
# 頂点は1433次元の二値ベクトルを特徴ベクトルとして持つ

# %%
zip_file = keras.utils.get_file(
    fname="cora.tgz",
    origin="https://linqs-data.soe.ucsc.edu/public/lbc/cora.tgz",
    extract=True,
)
data_dir = os.path.join(os.path.dirname(zip_file), "cora")
# Out:
# Downloading data from https://linqs-data.soe.ucsc.edu/public/lbc/cora.tgz
# 172032/168052 [==============================] - 0s 2us/step

# %%
citations = pd.read_csv(
    os.path.join(data_dir, "cora.cites"),
    sep="\t",
    header=None,
    names=["target", "source"],
)
print("Citations shape:", citations.shape)
# Out:
# Citations shape: (5429, 2)

# %%
citations.sample(frac=1).head()
# Out:
#       target   source
# 662     2665   578306
# 699     2698    99025
# 852     3229   444191
# 2429   23774  1106406
# 1674   10174    10186

# %%
column_names = ["paper_id"] + [f"term_{idx}" for idx in range(1433)] + ["subject"]
papers = pd.read_csv(
    os.path.join(data_dir, "cora.content"), sep="\t", header=None, names=column_names,
)
print("Papers shape:", papers.shape)
# Out:
# Papers shape: (2708, 1435)

# %%
papers
# Out:
#       paper_id  term_0  term_1  ...  term_1431  term_1432                 subject
# 0        31336       0       0  ...          0          0         Neural_Networks
# 1      1061127       0       0  ...          0          0           Rule_Learning
# 2      1106406       0       0  ...          0          0  Reinforcement_Learning
# 3        13195       0       0  ...          0          0  Reinforcement_Learning
# 4        37879       0       0  ...          0          0   Probabilistic_Methods
# ...        ...     ...     ...  ...        ...        ...                     ...
# 2703   1128975       0       0  ...          0          0      Genetic_Algorithms
# 2704   1128977       0       0  ...          0          0      Genetic_Algorithms
# 2705   1128978       0       0  ...          0          0      Genetic_Algorithms
# 2706    117328       0       0  ...          0          0              Case_Based
# 2707     24043       0       0  ...          0          0         Neural_Networks
#
# [2708 rows x 1435 columns]

# %%
class_values = sorted(papers["subject"].unique())
class_idx = {name: id for id, name in enumerate(class_values)}
paper_idx = {name: idx for idx, name in enumerate(sorted(papers["paper_id"].unique()))}

papers["paper_id"] = papers["paper_id"].apply(lambda name: paper_idx[name])
citations["source"] = citations["source"].apply(lambda name: paper_idx[name])
citations["target"] = citations["target"].apply(lambda name: paper_idx[name])
papers["subject"] = papers["subject"].apply(lambda value: class_idx[value])

# %%
# visualise citation network
plt.figure(figsize=(10, 10))
colors = papers["subject"].tolist()
cora_graph = nx.from_pandas_edgelist(citations.sample(n=1500))
subjects = list(papers[papers["paper_id"].isin(list(cora_graph.nodes))]["subject"])
nx.draw_spring(cora_graph, node_size=15, node_color=subjects)

# %%
# split dataset into train_data and test_data
train_data, test_data = [], []

for _, group_data in papers.groupby("subject"):
    # Select around 50% of the dataset for training.
    random_selection = np.random.rand(len(group_data.index)) <= 0.5
    train_data.append(group_data[random_selection])
    test_data.append(group_data[~random_selection])

train_data = pd.concat(train_data).sample(frac=1)
test_data = pd.concat(test_data).sample(frac=1)

print("Train data shape:", train_data.shape)
print("Test data shape:", test_data.shape)
# Out:
# Train data shape: (1352, 1435)
# Test data shape: (1356, 1435)

# %%
hidden_units = [32, 32]
learning_rate = 0.01
dropout_rate = 0.5
num_epochs = 300
batch_size = 256

# %%
def run_experiment(model, x_train, y_train):
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")]
    )
    
    early_stopping = keras.callbacks.EarlyStopping(
        monitor="val_acc", patience=50, restore_best_weights=True
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        epochs=num_epochs,
        batch_size=batch_size,
        validation_split=0.15,
        callbacks=[early_stopping]
    )

    return history

# %%
def display_learning_curves(history):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

    ax1.plot(history.history["loss"])
    ax1.plot(history.history["val_loss"])
    ax1.legend(["train", "test"], loc="upper right")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("Loss")

    ax2.plot(history.history["acc"])
    ax2.plot(history.history["val_acc"])
    ax2.legend(["train", "test"], loc="upper right")
    ax2.set_xlabel("Epochs")
    ax2.set_ylabel("Accuracy")
    plt.show()

# %%
# Feedforward Network
def create_ffn(hidden_units, dropout_rate, name=None):
    fnn_layers = []

    for units in hidden_units:
        fnn_layers.append(layers.BatchNormalization())
        fnn_layers.append(layers.Dropout(dropout_rate))
        fnn_layers.append(layers.Dense(units, activation=tf.nn.gelu))

    return keras.Sequential(fnn_layers, name=name)

# %%
feature_names = set(papers.columns) - {"paper_id", "subject"}
num_features = len(feature_names)
num_classes = len(class_idx)

# Create train and test features as a numpy array.
x_train = train_data[feature_names].to_numpy()
x_test = test_data[feature_names].to_numpy()
# Create train and test targets as a numpy array.
y_train = train_data["subject"]
y_test = test_data["subject"]

# %%
def create_baseline_model(hidden_units, num_classes, dropout_rate=0.2):
    inputs = layers.Input(shape=(num_features,), name="input_features")
    x = create_ffn(hidden_units, dropout_rate, name=f"ffn_block1")(inputs)
    for block_idx in range(4):
        # Create an FFN block.
        x1 = create_ffn(hidden_units, dropout_rate, name=f"ffn_block{block_idx + 2}")(x)
        # Add skip connection.
        x = layers.Add(name=f"skip_connection{block_idx + 2}")([x, x1])
    # Compute logits.
    logits = layers.Dense(num_classes, name="logits")(x)
    # Create the model.
    return keras.Model(inputs=inputs, outputs=logits, name="baseline")


baseline_model = create_baseline_model(hidden_units, num_classes, dropout_rate)
baseline_model.summary()
# Out:
# Model: "baseline"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_features (InputLayer)     [(None, 1433)]       0
# __________________________________________________________________________________________________
# ffn_block1 (Sequential)         (None, 32)           52804       input_features[0][0]
# __________________________________________________________________________________________________
# ffn_block2 (Sequential)         (None, 32)           2368        ffn_block1[0][0]
# __________________________________________________________________________________________________
# skip_connection2 (Add)          (None, 32)           0           ffn_block1[0][0]
#                                                                  ffn_block2[0][0]
# __________________________________________________________________________________________________
# ffn_block3 (Sequential)         (None, 32)           2368        skip_connection2[0][0]
# __________________________________________________________________________________________________
# skip_connection3 (Add)          (None, 32)           0           skip_connection2[0][0]
#                                                                  ffn_block3[0][0]
# __________________________________________________________________________________________________
# ffn_block4 (Sequential)         (None, 32)           2368        skip_connection3[0][0]
# __________________________________________________________________________________________________
# skip_connection4 (Add)          (None, 32)           0           skip_connection3[0][0]
#                                                                  ffn_block4[0][0]
# __________________________________________________________________________________________________
# ffn_block5 (Sequential)         (None, 32)           2368        skip_connection4[0][0]
# __________________________________________________________________________________________________
# skip_connection5 (Add)          (None, 32)           0           skip_connection4[0][0]
#                                                                  ffn_block5[0][0]
# __________________________________________________________________________________________________
# logits (Dense)                  (None, 7)            231         skip_connection5[0][0]
# ==================================================================================================
# Total params: 62,507
# Trainable params: 59,065
# Non-trainable params: 3,442
# __________________________________________________________________________________________________

# %%
history = run_experiment(baseline_model, x_train, y_train)
# Out:
# Epoch 1/300
# 5/5 [==============================] - 4s 128ms/step - loss: 3.2856 - acc: 0.1697 - val_loss: 1.9685 - val_acc: 0.1330
# Epoch 2/300
# 5/5 [==============================] - 0s 24ms/step - loss: 2.6137 - acc: 0.2106 - val_loss: 1.9315 - val_acc: 0.1379
# Epoch 3/300
# 5/5 [==============================] - 0s 26ms/step - loss: 2.2378 - acc: 0.2576 - val_loss: 1.9472 - val_acc: 0.1576
# Epoch 4/300
# 5/5 [==============================] - 0s 24ms/step - loss: 2.1417 - acc: 0.2228 - val_loss: 1.9520 - val_acc: 0.1675
# Epoch 5/300
# 5/5 [==============================] - 0s 24ms/step - loss: 1.9581 - acc: 0.2620 - val_loss: 1.9290 - val_acc: 0.2414
# Epoch 6/300
# 5/5 [==============================] - 0s 23ms/step - loss: 1.8896 - acc: 0.2707 - val_loss: 1.9005 - val_acc: 0.2512
# Epoch 7/300
# 5/5 [==============================] - 0s 25ms/step - loss: 1.8223 - acc: 0.3011 - val_loss: 1.8779 - val_acc: 0.3103
# Epoch 8/300
# 5/5 [==============================] - 0s 23ms/step - loss: 1.7262 - acc: 0.3299 - val_loss: 1.8458 - val_acc: 0.3990
# Epoch 9/300
# 5/5 [==============================] - 0s 25ms/step - loss: 1.6900 - acc: 0.3438 - val_loss: 1.8097 - val_acc: 0.4286
# Epoch 10/300
# 5/5 [==============================] - 0s 24ms/step - loss: 1.6007 - acc: 0.3873 - val_loss: 1.7784 - val_acc: 0.4335
# Epoch 11/300
# 5/5 [==============================] - 0s 23ms/step - loss: 1.5420 - acc: 0.4378 - val_loss: 1.7339 - val_acc: 0.4335
# Epoch 12/300
# 5/5 [==============================] - 0s 24ms/step - loss: 1.4483 - acc: 0.4421 - val_loss: 1.6748 - val_acc: 0.4483
# Epoch 13/300
# 5/5 [==============================] - 0s 25ms/step - loss: 1.3653 - acc: 0.5004 - val_loss: 1.6249 - val_acc: 0.4236
# Epoch 14/300
# 5/5 [==============================] - 0s 25ms/step - loss: 1.3278 - acc: 0.5187 - val_loss: 1.5439 - val_acc: 0.4483
# Epoch 15/300
# 5/5 [==============================] - 0s 24ms/step - loss: 1.2049 - acc: 0.5553 - val_loss: 1.4378 - val_acc: 0.5369
# Epoch 16/300
# 5/5 [==============================] - 0s 24ms/step - loss: 1.1698 - acc: 0.5944 - val_loss: 1.3395 - val_acc: 0.5764
# Epoch 17/300
# 5/5 [==============================] - 0s 24ms/step - loss: 1.0565 - acc: 0.6127 - val_loss: 1.2612 - val_acc: 0.5961
# Epoch 18/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.9786 - acc: 0.6493 - val_loss: 1.2127 - val_acc: 0.6207
# Epoch 19/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.9372 - acc: 0.6667 - val_loss: 1.2070 - val_acc: 0.5862
# Epoch 20/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.9295 - acc: 0.6667 - val_loss: 1.2629 - val_acc: 0.5517
# Epoch 21/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.8992 - acc: 0.6736 - val_loss: 1.2665 - val_acc: 0.5320
# Epoch 22/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.8055 - acc: 0.7145 - val_loss: 1.2249 - val_acc: 0.5271
# Epoch 23/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.8260 - acc: 0.7032 - val_loss: 1.2000 - val_acc: 0.5369
# Epoch 24/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7562 - acc: 0.7372 - val_loss: 1.1437 - val_acc: 0.5665
# Epoch 25/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.7256 - acc: 0.7450 - val_loss: 1.0757 - val_acc: 0.6207
# Epoch 26/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.7268 - acc: 0.7389 - val_loss: 1.0579 - val_acc: 0.6108
# Epoch 27/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.6587 - acc: 0.7485 - val_loss: 1.0594 - val_acc: 0.6010
# Epoch 28/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.6646 - acc: 0.7668 - val_loss: 1.0699 - val_acc: 0.6059
# Epoch 29/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.6734 - acc: 0.7659 - val_loss: 1.1278 - val_acc: 0.5911
# Epoch 30/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.6551 - acc: 0.7746 - val_loss: 1.1042 - val_acc: 0.5911
# Epoch 31/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.6117 - acc: 0.7859 - val_loss: 1.0331 - val_acc: 0.6355
# Epoch 32/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.5838 - acc: 0.8050 - val_loss: 0.9902 - val_acc: 0.6552
# Epoch 33/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.6279 - acc: 0.7676 - val_loss: 0.9844 - val_acc: 0.6502
# Epoch 34/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.6176 - acc: 0.7815 - val_loss: 0.9414 - val_acc: 0.6650
# Epoch 35/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.5551 - acc: 0.8016 - val_loss: 0.9879 - val_acc: 0.6305
# Epoch 36/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.5624 - acc: 0.7963 - val_loss: 0.9750 - val_acc: 0.6355
# Epoch 37/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.5741 - acc: 0.8033 - val_loss: 0.8870 - val_acc: 0.6798
# Epoch 38/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.5448 - acc: 0.7998 - val_loss: 0.8711 - val_acc: 0.6847
# Epoch 39/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.5441 - acc: 0.8233 - val_loss: 0.8812 - val_acc: 0.7094
# Epoch 40/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.5248 - acc: 0.7955 - val_loss: 0.9109 - val_acc: 0.6798
# Epoch 41/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.5713 - acc: 0.7920 - val_loss: 0.9494 - val_acc: 0.6650
# Epoch 42/300
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5510 - acc: 0.8172 - val_loss: 1.0317 - val_acc: 0.6256
# Epoch 43/300
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5192 - acc: 0.8181 - val_loss: 1.0978 - val_acc: 0.6010
# Epoch 44/300
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5546 - acc: 0.8007 - val_loss: 1.1072 - val_acc: 0.6108
# Epoch 45/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4789 - acc: 0.8399 - val_loss: 1.0231 - val_acc: 0.6502
# Epoch 46/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4914 - acc: 0.8338 - val_loss: 0.9491 - val_acc: 0.6798
# Epoch 47/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.5112 - acc: 0.8268 - val_loss: 0.8984 - val_acc: 0.6946
# Epoch 48/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.5090 - acc: 0.8155 - val_loss: 0.8894 - val_acc: 0.6995
# Epoch 49/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4665 - acc: 0.8416 - val_loss: 0.8889 - val_acc: 0.7044
# Epoch 50/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4794 - acc: 0.8242 - val_loss: 0.9060 - val_acc: 0.6847
# Epoch 51/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.5144 - acc: 0.8277 - val_loss: 0.9591 - val_acc: 0.6749
# Epoch 52/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.4923 - acc: 0.8346 - val_loss: 0.9477 - val_acc: 0.6749
# Epoch 53/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4853 - acc: 0.8390 - val_loss: 0.8685 - val_acc: 0.6798
# Epoch 54/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4909 - acc: 0.8303 - val_loss: 0.8343 - val_acc: 0.7094
# Epoch 55/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4369 - acc: 0.8512 - val_loss: 0.8517 - val_acc: 0.6946
# Epoch 56/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4654 - acc: 0.8320 - val_loss: 0.8725 - val_acc: 0.7044
# Epoch 57/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4817 - acc: 0.8381 - val_loss: 0.8828 - val_acc: 0.7044
# Epoch 58/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.5075 - acc: 0.8164 - val_loss: 0.8885 - val_acc: 0.7044
# Epoch 59/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4517 - acc: 0.8407 - val_loss: 0.8748 - val_acc: 0.7044
# Epoch 60/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4552 - acc: 0.8433 - val_loss: 0.9128 - val_acc: 0.6897
# Epoch 61/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4591 - acc: 0.8442 - val_loss: 0.9241 - val_acc: 0.6749
# Epoch 62/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4411 - acc: 0.8486 - val_loss: 0.8998 - val_acc: 0.7044
# Epoch 63/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4357 - acc: 0.8503 - val_loss: 0.9080 - val_acc: 0.7241
# Epoch 64/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4295 - acc: 0.8512 - val_loss: 0.9136 - val_acc: 0.7143
# Epoch 65/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4585 - acc: 0.8294 - val_loss: 0.9010 - val_acc: 0.7241
# Epoch 66/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.4472 - acc: 0.8399 - val_loss: 0.8923 - val_acc: 0.7241
# Epoch 67/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3847 - acc: 0.8607 - val_loss: 0.9351 - val_acc: 0.7044
# Epoch 68/300
# 5/5 [==============================] - 0s 32ms/step - loss: 0.4291 - acc: 0.8512 - val_loss: 0.9106 - val_acc: 0.7143
# Epoch 69/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4629 - acc: 0.8338 - val_loss: 0.8521 - val_acc: 0.7291
# Epoch 70/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3790 - acc: 0.8634 - val_loss: 0.8556 - val_acc: 0.7340
# Epoch 71/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3915 - acc: 0.8573 - val_loss: 0.8427 - val_acc: 0.7389
# Epoch 72/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4583 - acc: 0.8477 - val_loss: 0.8557 - val_acc: 0.7241
# Epoch 73/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4074 - acc: 0.8729 - val_loss: 0.8591 - val_acc: 0.7291
# Epoch 74/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4353 - acc: 0.8555 - val_loss: 0.8704 - val_acc: 0.7291
# Epoch 75/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4267 - acc: 0.8494 - val_loss: 0.8673 - val_acc: 0.7438
# Epoch 76/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4215 - acc: 0.8573 - val_loss: 0.8724 - val_acc: 0.7488
# Epoch 77/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4155 - acc: 0.8581 - val_loss: 0.8754 - val_acc: 0.7291
# Epoch 78/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3939 - acc: 0.8538 - val_loss: 0.8748 - val_acc: 0.7389
# Epoch 79/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4173 - acc: 0.8599 - val_loss: 0.8817 - val_acc: 0.7340
# Epoch 80/300
# 5/5 [==============================] - 0s 31ms/step - loss: 0.4127 - acc: 0.8486 - val_loss: 0.9039 - val_acc: 0.7340
# Epoch 81/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3856 - acc: 0.8625 - val_loss: 0.9018 - val_acc: 0.7291
# Epoch 82/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3732 - acc: 0.8651 - val_loss: 0.8859 - val_acc: 0.7438
# Epoch 83/300
# 5/5 [==============================] - 0s 29ms/step - loss: 0.4156 - acc: 0.8590 - val_loss: 0.8734 - val_acc: 0.7438
# Epoch 84/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4153 - acc: 0.8555 - val_loss: 0.8884 - val_acc: 0.7340
# Epoch 85/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4177 - acc: 0.8590 - val_loss: 0.8949 - val_acc: 0.7291
# Epoch 86/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3861 - acc: 0.8660 - val_loss: 0.9100 - val_acc: 0.7389
# Epoch 87/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3728 - acc: 0.8747 - val_loss: 0.9281 - val_acc: 0.7340
# Epoch 88/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3896 - acc: 0.8642 - val_loss: 0.9318 - val_acc: 0.7241
# Epoch 89/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3578 - acc: 0.8773 - val_loss: 0.9103 - val_acc: 0.7438
# Epoch 90/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3969 - acc: 0.8642 - val_loss: 0.9250 - val_acc: 0.7537
# Epoch 91/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4011 - acc: 0.8564 - val_loss: 0.9477 - val_acc: 0.7291
# Epoch 92/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3740 - acc: 0.8729 - val_loss: 0.9723 - val_acc: 0.7438
# Epoch 93/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4028 - acc: 0.8634 - val_loss: 0.9858 - val_acc: 0.7340
# Epoch 94/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4150 - acc: 0.8599 - val_loss: 0.9684 - val_acc: 0.7291
# Epoch 95/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4015 - acc: 0.8564 - val_loss: 0.9464 - val_acc: 0.7192
# Epoch 96/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3720 - acc: 0.8686 - val_loss: 0.9590 - val_acc: 0.7143
# Epoch 97/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3565 - acc: 0.8808 - val_loss: 0.9712 - val_acc: 0.7143
# Epoch 98/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3566 - acc: 0.8842 - val_loss: 0.9884 - val_acc: 0.7291
# Epoch 99/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4020 - acc: 0.8590 - val_loss: 1.0180 - val_acc: 0.7143
# Epoch 100/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3763 - acc: 0.8634 - val_loss: 1.0630 - val_acc: 0.7241
# Epoch 101/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3686 - acc: 0.8773 - val_loss: 1.0612 - val_acc: 0.6995
# Epoch 102/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3891 - acc: 0.8755 - val_loss: 1.0379 - val_acc: 0.7044
# Epoch 103/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3605 - acc: 0.8721 - val_loss: 1.0323 - val_acc: 0.6995
# Epoch 104/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3959 - acc: 0.8677 - val_loss: 1.0680 - val_acc: 0.7044
# Epoch 105/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3425 - acc: 0.8764 - val_loss: 1.1447 - val_acc: 0.6995
# Epoch 106/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3836 - acc: 0.8581 - val_loss: 1.0882 - val_acc: 0.6897
# Epoch 107/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4021 - acc: 0.8538 - val_loss: 1.0727 - val_acc: 0.6995
# Epoch 108/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3804 - acc: 0.8590 - val_loss: 1.0797 - val_acc: 0.6995
# Epoch 109/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3526 - acc: 0.8782 - val_loss: 1.1283 - val_acc: 0.6897
# Epoch 110/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3523 - acc: 0.8825 - val_loss: 1.1846 - val_acc: 0.6601
# Epoch 111/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3574 - acc: 0.8851 - val_loss: 1.1330 - val_acc: 0.6946
# Epoch 112/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3596 - acc: 0.8747 - val_loss: 1.1407 - val_acc: 0.6847
# Epoch 113/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3879 - acc: 0.8651 - val_loss: 1.1519 - val_acc: 0.6995
# Epoch 114/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3578 - acc: 0.8799 - val_loss: 1.1716 - val_acc: 0.6847
# Epoch 115/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3500 - acc: 0.8842 - val_loss: 1.2180 - val_acc: 0.6897
# Epoch 116/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4215 - acc: 0.8529 - val_loss: 1.2023 - val_acc: 0.6995
# Epoch 117/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3191 - acc: 0.8956 - val_loss: 1.1681 - val_acc: 0.6946
# Epoch 118/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4063 - acc: 0.8590 - val_loss: 1.1611 - val_acc: 0.6847
# Epoch 119/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3448 - acc: 0.8877 - val_loss: 1.1627 - val_acc: 0.6847
# Epoch 120/300
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3646 - acc: 0.8547 - val_loss: 1.1725 - val_acc: 0.6798
# Epoch 121/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3676 - acc: 0.8712 - val_loss: 1.1520 - val_acc: 0.6897
# Epoch 122/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3687 - acc: 0.8947 - val_loss: 1.1573 - val_acc: 0.6798
# Epoch 123/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4132 - acc: 0.8607 - val_loss: 1.1856 - val_acc: 0.6798
# Epoch 124/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3319 - acc: 0.8842 - val_loss: 1.1655 - val_acc: 0.6946
# Epoch 125/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3331 - acc: 0.8808 - val_loss: 1.1338 - val_acc: 0.6946
# Epoch 126/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3398 - acc: 0.8956 - val_loss: 1.1449 - val_acc: 0.7094
# Epoch 127/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3364 - acc: 0.8842 - val_loss: 1.1689 - val_acc: 0.7044
# Epoch 128/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3534 - acc: 0.8903 - val_loss: 1.1832 - val_acc: 0.7044
# Epoch 129/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3934 - acc: 0.8660 - val_loss: 1.1642 - val_acc: 0.6995
# Epoch 130/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3337 - acc: 0.8825 - val_loss: 1.1904 - val_acc: 0.6847
# Epoch 131/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4009 - acc: 0.8686 - val_loss: 1.1682 - val_acc: 0.6798
# Epoch 132/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3324 - acc: 0.8773 - val_loss: 1.1267 - val_acc: 0.6897
# Epoch 133/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3626 - acc: 0.8799 - val_loss: 1.1050 - val_acc: 0.6847
# Epoch 134/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3646 - acc: 0.8738 - val_loss: 1.1271 - val_acc: 0.6897
# Epoch 135/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3710 - acc: 0.8729 - val_loss: 1.1491 - val_acc: 0.6798
# Epoch 136/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3497 - acc: 0.8747 - val_loss: 1.1447 - val_acc: 0.6946
# Epoch 137/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3698 - acc: 0.8616 - val_loss: 1.1309 - val_acc: 0.6946
# Epoch 138/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3571 - acc: 0.8721 - val_loss: 1.1574 - val_acc: 0.6995
# Epoch 139/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3537 - acc: 0.8721 - val_loss: 1.1753 - val_acc: 0.7044
# Epoch 140/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3608 - acc: 0.8808 - val_loss: 1.1982 - val_acc: 0.6749

# %%
display_learning_curves(history)

# %%
_, test_accuracy = baseline_model.evaluate(x=x_test, y=y_test, verbose=0)
print(f"Test accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# Test accuracy: 73.01%

# %%
def generate_random_instances(num_instances):
    token_probability = x_train.mean(axis=0)
    instances = []
    for _ in range(num_instances):
        probabilities = np.random.uniform(size=len(token_probability))
        instance = (probabilities <= token_probability).astype(int)
        instances.append(instance)

    return np.array(instances)


def display_class_probabilities(probabilities):
    for instance_idx, probs in enumerate(probabilities):
        print(f"Instance {instance_idx + 1}:")
        for class_idx, prob in enumerate(probs):
            print(f"- {class_values[class_idx]}: {round(prob * 100, 2)}%")

# %%
new_instances = generate_random_instances(num_classes)
logits = baseline_model.predict(new_instances)
probabilities = keras.activations.softmax(tf.convert_to_tensor(logits)).numpy()
display_class_probabilities(probabilities)
# Out:
# Instance 1:
# - Case_Based: 9.63%
# - Genetic_Algorithms: 7.6%
# - Neural_Networks: 9.18%
# - Probabilistic_Methods: 31.13%
# - Reinforcement_Learning: 0.63%
# - Rule_Learning: 17.67%
# - Theory: 24.16%
# Instance 2:
# - Case_Based: 0.1%
# - Genetic_Algorithms: 0.21%
# - Neural_Networks: 53.27%
# - Probabilistic_Methods: 1.32%
# - Reinforcement_Learning: 0.09%
# - Rule_Learning: 0.02%
# - Theory: 44.98%
# Instance 3:
# - Case_Based: 0.82%
# - Genetic_Algorithms: 15.25%
# - Neural_Networks: 15.91%
# - Probabilistic_Methods: 43.7%
# - Reinforcement_Learning: 3.1%
# - Rule_Learning: 1.39%
# - Theory: 19.82%
# Instance 4:
# - Case_Based: 0.32%
# - Genetic_Algorithms: 0.32%
# - Neural_Networks: 2.48%
# - Probabilistic_Methods: 92.52%
# - Reinforcement_Learning: 0.2%
# - Rule_Learning: 0.12%
# - Theory: 4.05%
# Instance 5:
# - Case_Based: 9.23%
# - Genetic_Algorithms: 1.91%
# - Neural_Networks: 6.26%
# - Probabilistic_Methods: 2.19%
# - Reinforcement_Learning: 0.56%
# - Rule_Learning: 61.41%
# - Theory: 18.44%
# Instance 6:
# - Case_Based: 0.05%
# - Genetic_Algorithms: 0.32%
# - Neural_Networks: 10.72%
# - Probabilistic_Methods: 87.33%
# - Reinforcement_Learning: 0.2%
# - Rule_Learning: 0.09%
# - Theory: 1.29%
# Instance 7:
# - Case_Based: 1.05%
# - Genetic_Algorithms: 26.59%
# - Neural_Networks: 8.32%
# - Probabilistic_Methods: 1.29%
# - Reinforcement_Learning: 61.63%
# - Rule_Learning: 0.22%
# - Theory: 0.9%

# %%
# GNN

# %%
# Create an edges array (sparse adjacency matrix) of shape [2, num_edges].
edges = citations[["source", "target"]].to_numpy().T
# Create an edge weights array of ones.
edge_weights = tf.ones(shape=edges.shape[1])
# Create a node features array of shape [num_nodes, num_features].
node_features = tf.cast(
    papers.sort_values("paper_id")[feature_names].to_numpy(), dtype=tf.dtypes.float32
)
# Create graph info tuple with node_features, edges, and edge_weights.
graph_info = (node_features, edges, edge_weights)

print("Edges shape:", edges.shape)
print("Nodes shape:", node_features.shape)
# Out:
# Edges shape: (2, 5429)
# Nodes shape: (2708, 1433)

# %%
class GraphConvLayer(layers.Layer):
    def __init__(
        self,
        hidden_units,
        dropout_rate=0.2,
        aggregation_type="mean",
        combination_type="concat",
        normalize=False,
        *args,
        **kwargs,
    ):
        super(GraphConvLayer, self).__init__(*args, **kwargs)

        self.aggregation_type = aggregation_type
        self.combination_type = combination_type
        self.normalize = normalize

        self.ffn_prepare = create_ffn(hidden_units, dropout_rate)
        if self.combination_type == "gated":
            self.update_fn = layers.GRU(
                units=hidden_units,
                activation="tanh",
                recurrent_activation="sigmoid",
                dropout=dropout_rate,
                return_state=True,
                recurrent_dropout=dropout_rate,
            )
        else:
            self.update_fn = create_ffn(hidden_units, dropout_rate)

    def prepare(self, node_repesentations, weights=None):
        # node_repesentations shape is [num_edges, embedding_dim].
        messages = self.ffn_prepare(node_repesentations)
        if weights is not None:
            messages = messages * tf.expand_dims(weights, -1)
        return messages

    def aggregate(self, node_indices, neighbour_messages):
        # node_indices shape is [num_edges].
        # neighbour_messages shape: [num_edges, representation_dim].
        num_nodes = tf.math.reduce_max(node_indices) + 1
        if self.aggregation_type == "sum":
            aggregated_message = tf.math.unsorted_segment_sum(
                neighbour_messages, node_indices, num_segments=num_nodes
            )
        elif self.aggregation_type == "mean":
            aggregated_message = tf.math.unsorted_segment_mean(
                neighbour_messages, node_indices, num_segments=num_nodes
            )
        elif self.aggregation_type == "max":
            aggregated_message = tf.math.unsorted_segment_max(
                neighbour_messages, node_indices, num_segments=num_nodes
            )
        else:
            raise ValueError(f"Invalid aggregation type: {self.aggregation_type}.")

        return aggregated_message

    def update(self, node_repesentations, aggregated_messages):
        # node_repesentations shape is [num_nodes, representation_dim].
        # aggregated_messages shape is [num_nodes, representation_dim].
        if self.combination_type == "gru":
            # Create a sequence of two elements for the GRU layer.
            h = tf.stack([node_repesentations, aggregated_messages], axis=1)
        elif self.combination_type == "concat":
            # Concatenate the node_repesentations and aggregated_messages.
            h = tf.concat([node_repesentations, aggregated_messages], axis=1)
        elif self.combination_type == "add":
            # Add node_repesentations and aggregated_messages.
            h = node_repesentations + aggregated_messages
        else:
            raise ValueError(f"Invalid combination type: {self.combination_type}.")

        # Apply the processing function.
        node_embeddings = self.update_fn(h)
        if self.combination_type == "gru":
            node_embeddings = tf.unstack(node_embeddings, axis=1)[-1]

        if self.normalize:
            node_embeddings = tf.nn.l2_normalize(node_embeddings, axis=-1)
        return node_embeddings

    def call(self, inputs):
        """Process the inputs to produce the node_embeddings.

        inputs: a tuple of three elements: node_repesentations, edges, edge_weights.
        Returns: node_embeddings of shape [num_nodes, representation_dim].
        """

        node_repesentations, edges, edge_weights = inputs
        # Get node_indices (source) and neighbour_indices (target) from edges.
        node_indices, neighbour_indices = edges[0], edges[1]
        # neighbour_repesentations shape is [num_edges, representation_dim].
        neighbour_repesentations = tf.gather(node_repesentations, neighbour_indices)

        # Prepare the messages of the neighbours.
        neighbour_messages = self.prepare(neighbour_repesentations, edge_weights)
        # Aggregate the neighbour messages.
        aggregated_messages = self.aggregate(node_indices, neighbour_messages)
        # Update the node embedding with the neighbour messages.
        return self.update(node_repesentations, aggregated_messages)

# %%
class GNNNodeClassifier(tf.keras.Model):
    def __init__(
        self,
        graph_info,
        num_classes,
        hidden_units,
        aggregation_type="sum",
        combination_type="concat",
        dropout_rate=0.2,
        normalize=True,
        *args,
        **kwargs,
    ):
        super(GNNNodeClassifier, self).__init__(*args, **kwargs)

        # Unpack graph_info to three elements: node_features, edges, and edge_weight.
        node_features, edges, edge_weights = graph_info
        self.node_features = node_features
        self.edges = edges
        self.edge_weights = edge_weights
        # Set edge_weights to ones if not provided.
        if self.edge_weights is None:
            self.edge_weights = tf.ones(shape=edges.shape[1])
        # Scale edge_weights to sum to 1.
        self.edge_weights = self.edge_weights / tf.math.reduce_sum(self.edge_weights)

        # Create a process layer.
        self.preprocess = create_ffn(hidden_units, dropout_rate, name="preprocess")
        # Create the first GraphConv layer.
        self.conv1 = GraphConvLayer(
            hidden_units,
            dropout_rate,
            aggregation_type,
            combination_type,
            normalize,
            name="graph_conv1",
        )
        # Create the second GraphConv layer.
        self.conv2 = GraphConvLayer(
            hidden_units,
            dropout_rate,
            aggregation_type,
            combination_type,
            normalize,
            name="graph_conv2",
        )
        # Create a postprocess layer.
        self.postprocess = create_ffn(hidden_units, dropout_rate, name="postprocess")
        # Create a compute logits layer.
        self.compute_logits = layers.Dense(units=num_classes, name="logits")

    def call(self, input_node_indices):
        # Preprocess the node_features to produce node representations.
        x = self.preprocess(self.node_features)
        # Apply the first graph conv layer.
        x1 = self.conv1((x, self.edges, self.edge_weights))
        # Skip connection.
        x = x1 + x
        # Apply the second graph conv layer.
        x2 = self.conv2((x, self.edges, self.edge_weights))
        # Skip connection.
        x = x2 + x
        # Postprocess node embedding.
        x = self.postprocess(x)
        # Fetch node embeddings for the input node_indices.
        node_embeddings = tf.squeeze(tf.gather(x, input_node_indices))
        # Compute logits
        return self.compute_logits(node_embeddings)

# %%
gnn_model = GNNNodeClassifier(
    graph_info=graph_info,
    num_classes=num_classes,
    hidden_units=hidden_units,
    dropout_rate=dropout_rate,
    name="gnn_model",
)

print("GNN output shape:", gnn_model([1, 10, 100]))

gnn_model.summary()
# Out:
# GNN output shape: tf.Tensor(
# [[ 0.18764889  0.03787652  0.06460396 -0.04018654  0.11784144  0.10133038
#    0.02737869]
#  [-0.06358135  0.06085556 -0.02961819 -0.03311957  0.13858816 -0.01272357
#   -0.03934512]
#  [ 0.03464599  0.17174393  0.10629413 -0.02428859  0.06109162  0.00161106
#   -0.14660424]], shape=(3, 7), dtype=float32)
# Model: "gnn_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# preprocess (Sequential)      (2708, 32)                52804
# _________________________________________________________________
# graph_conv1 (GraphConvLayer) multiple                  5888
# _________________________________________________________________
# graph_conv2 (GraphConvLayer) multiple                  5888
# _________________________________________________________________
# postprocess (Sequential)     (2708, 32)                2368
# _________________________________________________________________
# logits (Dense)               multiple                  231
# =================================================================
# Total params: 67,179
# Trainable params: 63,481
# Non-trainable params: 3,698
# _________________________________________________________________

# %%
x_train = train_data.paper_id.to_numpy()
history = run_experiment(gnn_model, x_train, y_train)
# Out:
# Epoch 1/300
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# 5/5 [==============================] - 5s 300ms/step - loss: 2.2177 - acc: 0.1767 - val_loss: 1.9103 - val_acc: 0.2956
# Epoch 2/300
# 5/5 [==============================] - 1s 173ms/step - loss: 1.9936 - acc: 0.2446 - val_loss: 1.8843 - val_acc: 0.3054
# Epoch 3/300
# 5/5 [==============================] - 1s 172ms/step - loss: 1.9322 - acc: 0.2541 - val_loss: 1.8757 - val_acc: 0.3054
# Epoch 4/300
# 5/5 [==============================] - 1s 175ms/step - loss: 1.8791 - acc: 0.2837 - val_loss: 1.8736 - val_acc: 0.3054
# Epoch 5/300
# 5/5 [==============================] - 1s 178ms/step - loss: 1.8758 - acc: 0.2742 - val_loss: 1.8671 - val_acc: 0.3054
# Epoch 6/300
# 5/5 [==============================] - 1s 177ms/step - loss: 1.8734 - acc: 0.2855 - val_loss: 1.8563 - val_acc: 0.3054
# Epoch 7/300
# 5/5 [==============================] - 1s 179ms/step - loss: 1.8431 - acc: 0.2968 - val_loss: 1.8476 - val_acc: 0.3054
# Epoch 8/300
# 5/5 [==============================] - 1s 174ms/step - loss: 1.8377 - acc: 0.2950 - val_loss: 1.8417 - val_acc: 0.3054
# Epoch 9/300
# 5/5 [==============================] - 1s 172ms/step - loss: 1.8386 - acc: 0.2907 - val_loss: 1.8340 - val_acc: 0.3054
# Epoch 10/300
# 5/5 [==============================] - 1s 173ms/step - loss: 1.8152 - acc: 0.3072 - val_loss: 1.8273 - val_acc: 0.3054
# Epoch 11/300
# 5/5 [==============================] - 1s 174ms/step - loss: 1.8000 - acc: 0.3029 - val_loss: 1.8113 - val_acc: 0.3054
# Epoch 12/300
# 5/5 [==============================] - 1s 173ms/step - loss: 1.7801 - acc: 0.3046 - val_loss: 1.7754 - val_acc: 0.3054
# Epoch 13/300
# 5/5 [==============================] - 1s 183ms/step - loss: 1.7711 - acc: 0.3107 - val_loss: 1.7235 - val_acc: 0.3103
# Epoch 14/300
# 5/5 [==============================] - 1s 177ms/step - loss: 1.7140 - acc: 0.3220 - val_loss: 1.6585 - val_acc: 0.3251
# Epoch 15/300
# 5/5 [==============================] - 1s 174ms/step - loss: 1.7052 - acc: 0.3272 - val_loss: 1.6081 - val_acc: 0.3498
# Epoch 16/300
# 5/5 [==============================] - 1s 173ms/step - loss: 1.6801 - acc: 0.3507 - val_loss: 1.5573 - val_acc: 0.3596
# Epoch 17/300
# 5/5 [==============================] - 1s 169ms/step - loss: 1.6041 - acc: 0.3795 - val_loss: 1.4999 - val_acc: 0.3941
# Epoch 18/300
# 5/5 [==============================] - 1s 175ms/step - loss: 1.5617 - acc: 0.3969 - val_loss: 1.4625 - val_acc: 0.4039
# Epoch 19/300
# 5/5 [==============================] - 1s 172ms/step - loss: 1.5213 - acc: 0.4430 - val_loss: 1.4425 - val_acc: 0.4089
# Epoch 20/300
# 5/5 [==============================] - 1s 175ms/step - loss: 1.4577 - acc: 0.4378 - val_loss: 1.4957 - val_acc: 0.4187
# Epoch 21/300
# 5/5 [==============================] - 1s 175ms/step - loss: 1.3704 - acc: 0.4926 - val_loss: 1.6030 - val_acc: 0.4236
# Epoch 22/300
# 5/5 [==============================] - 1s 173ms/step - loss: 1.2801 - acc: 0.5152 - val_loss: 1.4914 - val_acc: 0.4828
# Epoch 23/300
# 5/5 [==============================] - 1s 174ms/step - loss: 1.2843 - acc: 0.5187 - val_loss: 1.3672 - val_acc: 0.4926
# Epoch 24/300
# 5/5 [==============================] - 1s 171ms/step - loss: 1.2420 - acc: 0.5466 - val_loss: 1.4314 - val_acc: 0.5271
# Epoch 25/300
# 5/5 [==============================] - 1s 178ms/step - loss: 1.2439 - acc: 0.5570 - val_loss: 1.3674 - val_acc: 0.5271
# Epoch 26/300
# 5/5 [==============================] - 1s 175ms/step - loss: 1.1693 - acc: 0.5657 - val_loss: 1.2980 - val_acc: 0.5271
# Epoch 27/300
# 5/5 [==============================] - 1s 178ms/step - loss: 1.1451 - acc: 0.5970 - val_loss: 1.3491 - val_acc: 0.5369
# Epoch 28/300
# 5/5 [==============================] - 1s 175ms/step - loss: 1.0503 - acc: 0.6319 - val_loss: 1.5505 - val_acc: 0.5567
# Epoch 29/300
# 5/5 [==============================] - 1s 177ms/step - loss: 1.0937 - acc: 0.6127 - val_loss: 1.7714 - val_acc: 0.5567
# Epoch 30/300
# 5/5 [==============================] - 1s 175ms/step - loss: 1.0703 - acc: 0.6266 - val_loss: 1.9117 - val_acc: 0.5517
# Epoch 31/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.9831 - acc: 0.6475 - val_loss: 1.8167 - val_acc: 0.5468
# Epoch 32/300
# 5/5 [==============================] - 1s 177ms/step - loss: 1.0105 - acc: 0.6554 - val_loss: 1.7613 - val_acc: 0.5714
# Epoch 33/300
# 5/5 [==============================] - 1s 173ms/step - loss: 0.9846 - acc: 0.6588 - val_loss: 1.5775 - val_acc: 0.5764
# Epoch 34/300
# 5/5 [==============================] - 1s 180ms/step - loss: 0.9575 - acc: 0.6606 - val_loss: 1.2844 - val_acc: 0.5911
# Epoch 35/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.9480 - acc: 0.6823 - val_loss: 1.1798 - val_acc: 0.6059
# Epoch 36/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.9030 - acc: 0.6910 - val_loss: 1.2271 - val_acc: 0.6158
# Epoch 37/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.9343 - acc: 0.6641 - val_loss: 1.5327 - val_acc: 0.6305
# Epoch 38/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.8322 - acc: 0.7041 - val_loss: 1.3944 - val_acc: 0.6404
# Epoch 39/300
# 5/5 [==============================] - 1s 171ms/step - loss: 0.8579 - acc: 0.7084 - val_loss: 1.2311 - val_acc: 0.6749
# Epoch 40/300
# 5/5 [==============================] - 1s 179ms/step - loss: 0.8418 - acc: 0.7250 - val_loss: 1.1944 - val_acc: 0.6798
# Epoch 41/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.8285 - acc: 0.7111 - val_loss: 1.1310 - val_acc: 0.6700
# Epoch 42/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.8328 - acc: 0.7258 - val_loss: 1.0388 - val_acc: 0.7094
# Epoch 43/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.7991 - acc: 0.7302 - val_loss: 0.9496 - val_acc: 0.6847
# Epoch 44/300
# 5/5 [==============================] - 1s 177ms/step - loss: 0.7742 - acc: 0.7528 - val_loss: 0.9361 - val_acc: 0.6798
# Epoch 45/300
# 5/5 [==============================] - 1s 178ms/step - loss: 0.7315 - acc: 0.7520 - val_loss: 1.0111 - val_acc: 0.6798
# Epoch 46/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.7657 - acc: 0.7450 - val_loss: 0.9636 - val_acc: 0.6749
# Epoch 47/300
# 5/5 [==============================] - 1s 178ms/step - loss: 0.7663 - acc: 0.7389 - val_loss: 0.9179 - val_acc: 0.6847
# Epoch 48/300
# 5/5 [==============================] - 1s 182ms/step - loss: 0.7199 - acc: 0.7581 - val_loss: 0.8850 - val_acc: 0.6946
# Epoch 49/300
# 5/5 [==============================] - 1s 178ms/step - loss: 0.6708 - acc: 0.7815 - val_loss: 0.8692 - val_acc: 0.7044
# Epoch 50/300
# 5/5 [==============================] - 1s 177ms/step - loss: 0.6761 - acc: 0.7755 - val_loss: 0.8918 - val_acc: 0.7192
# Epoch 51/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.6813 - acc: 0.7728 - val_loss: 0.8885 - val_acc: 0.7094
# Epoch 52/300
# 5/5 [==============================] - 1s 181ms/step - loss: 0.7503 - acc: 0.7467 - val_loss: 0.8827 - val_acc: 0.7094
# Epoch 53/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.6593 - acc: 0.7772 - val_loss: 0.8796 - val_acc: 0.7044
# Epoch 54/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.6529 - acc: 0.7798 - val_loss: 0.9038 - val_acc: 0.7094
# Epoch 55/300
# 5/5 [==============================] - 1s 172ms/step - loss: 0.7116 - acc: 0.7633 - val_loss: 0.9070 - val_acc: 0.6897
# Epoch 56/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.6844 - acc: 0.7815 - val_loss: 0.8718 - val_acc: 0.6995
# Epoch 57/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.6936 - acc: 0.7781 - val_loss: 0.8875 - val_acc: 0.7094
# Epoch 58/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.6841 - acc: 0.7633 - val_loss: 0.8488 - val_acc: 0.7044
# Epoch 59/300
# 5/5 [==============================] - 1s 177ms/step - loss: 0.5883 - acc: 0.8016 - val_loss: 0.8170 - val_acc: 0.7340
# Epoch 60/300
# 5/5 [==============================] - 1s 179ms/step - loss: 0.6802 - acc: 0.7859 - val_loss: 0.8206 - val_acc: 0.7192
# Epoch 61/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.5967 - acc: 0.7946 - val_loss: 0.9012 - val_acc: 0.7143
# Epoch 62/300
# 5/5 [==============================] - 1s 178ms/step - loss: 0.5956 - acc: 0.7937 - val_loss: 1.1017 - val_acc: 0.6650
# Epoch 63/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.6346 - acc: 0.7894 - val_loss: 1.0911 - val_acc: 0.6502
# Epoch 64/300
# 5/5 [==============================] - 1s 179ms/step - loss: 0.6061 - acc: 0.7990 - val_loss: 0.9727 - val_acc: 0.6946
# Epoch 65/300
# 5/5 [==============================] - 1s 177ms/step - loss: 0.5820 - acc: 0.8172 - val_loss: 0.8633 - val_acc: 0.7094
# Epoch 66/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.5557 - acc: 0.8303 - val_loss: 0.8913 - val_acc: 0.7143
# Epoch 67/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.6163 - acc: 0.7946 - val_loss: 0.9300 - val_acc: 0.7044
# Epoch 68/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.5231 - acc: 0.8138 - val_loss: 0.9496 - val_acc: 0.7094
# Epoch 69/300
# 5/5 [==============================] - 1s 179ms/step - loss: 0.5745 - acc: 0.8129 - val_loss: 0.8767 - val_acc: 0.7389
# Epoch 70/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.5557 - acc: 0.8138 - val_loss: 0.8313 - val_acc: 0.7438
# Epoch 71/300
# 5/5 [==============================] - 1s 179ms/step - loss: 0.5788 - acc: 0.8024 - val_loss: 0.8427 - val_acc: 0.7340
# Epoch 72/300
# 5/5 [==============================] - 1s 182ms/step - loss: 0.5415 - acc: 0.8285 - val_loss: 0.8390 - val_acc: 0.7340
# Epoch 73/300
# 5/5 [==============================] - 1s 177ms/step - loss: 0.5154 - acc: 0.8285 - val_loss: 0.8198 - val_acc: 0.7241
# Epoch 74/300
# 5/5 [==============================] - 1s 173ms/step - loss: 0.5315 - acc: 0.8198 - val_loss: 0.9193 - val_acc: 0.7143
# Epoch 75/300
# 5/5 [==============================] - 1s 173ms/step - loss: 0.5285 - acc: 0.8346 - val_loss: 0.9307 - val_acc: 0.7143
# Epoch 76/300
# 5/5 [==============================] - 1s 180ms/step - loss: 0.5114 - acc: 0.8355 - val_loss: 0.8687 - val_acc: 0.7241
# Epoch 77/300
# 5/5 [==============================] - 1s 173ms/step - loss: 0.5049 - acc: 0.8407 - val_loss: 0.8584 - val_acc: 0.7192
# Epoch 78/300
# 5/5 [==============================] - 1s 177ms/step - loss: 0.5095 - acc: 0.8364 - val_loss: 0.8860 - val_acc: 0.7044
# Epoch 79/300
# 5/5 [==============================] - 1s 178ms/step - loss: 0.5168 - acc: 0.8329 - val_loss: 0.8361 - val_acc: 0.7192
# Epoch 80/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.4939 - acc: 0.8407 - val_loss: 0.7874 - val_acc: 0.7389
# Epoch 81/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.5377 - acc: 0.8216 - val_loss: 0.8150 - val_acc: 0.7241
# Epoch 82/300
# 5/5 [==============================] - 1s 173ms/step - loss: 0.4841 - acc: 0.8381 - val_loss: 0.8296 - val_acc: 0.7340
# Epoch 83/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.5085 - acc: 0.8346 - val_loss: 0.8719 - val_acc: 0.7241
# Epoch 84/300
# 5/5 [==============================] - 1s 179ms/step - loss: 0.5102 - acc: 0.8285 - val_loss: 0.9377 - val_acc: 0.7340
# Epoch 85/300
# 5/5 [==============================] - 1s 179ms/step - loss: 0.5110 - acc: 0.8399 - val_loss: 0.9364 - val_acc: 0.7241
# Epoch 86/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.5132 - acc: 0.8338 - val_loss: 0.9074 - val_acc: 0.7291
# Epoch 87/300
# 5/5 [==============================] - 1s 178ms/step - loss: 0.5341 - acc: 0.8364 - val_loss: 0.7884 - val_acc: 0.7438
# Epoch 88/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.5018 - acc: 0.8512 - val_loss: 0.7166 - val_acc: 0.7833
# Epoch 89/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.5214 - acc: 0.8338 - val_loss: 0.7330 - val_acc: 0.7685
# Epoch 90/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.4757 - acc: 0.8399 - val_loss: 0.7465 - val_acc: 0.7685
# Epoch 91/300
# 5/5 [==============================] - 1s 177ms/step - loss: 0.4629 - acc: 0.8651 - val_loss: 0.7589 - val_acc: 0.7734
# Epoch 92/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.4664 - acc: 0.8503 - val_loss: 0.7244 - val_acc: 0.7783
# Epoch 93/300
# 5/5 [==============================] - 1s 180ms/step - loss: 0.4243 - acc: 0.8616 - val_loss: 0.7197 - val_acc: 0.7931
# Epoch 94/300
# 5/5 [==============================] - 1s 178ms/step - loss: 0.4508 - acc: 0.8442 - val_loss: 0.7428 - val_acc: 0.7882
# Epoch 95/300
# 5/5 [==============================] - 1s 180ms/step - loss: 0.5069 - acc: 0.8407 - val_loss: 0.7493 - val_acc: 0.7931
# Epoch 96/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.5091 - acc: 0.8486 - val_loss: 0.7407 - val_acc: 0.7882
# Epoch 97/300
# 5/5 [==============================] - 1s 178ms/step - loss: 0.4732 - acc: 0.8581 - val_loss: 0.7328 - val_acc: 0.7635
# Epoch 98/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.4301 - acc: 0.8538 - val_loss: 0.7474 - val_acc: 0.7734
# Epoch 99/300
# 5/5 [==============================] - 1s 178ms/step - loss: 0.4681 - acc: 0.8573 - val_loss: 0.7479 - val_acc: 0.7734
# Epoch 100/300
# 5/5 [==============================] - 1s 178ms/step - loss: 0.4656 - acc: 0.8512 - val_loss: 0.7897 - val_acc: 0.7635
# Epoch 101/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.4765 - acc: 0.8512 - val_loss: 0.8218 - val_acc: 0.7586
# Epoch 102/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.4720 - acc: 0.8520 - val_loss: 0.8001 - val_acc: 0.7734
# Epoch 103/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.4436 - acc: 0.8616 - val_loss: 0.7855 - val_acc: 0.7635
# Epoch 104/300
# 5/5 [==============================] - 1s 173ms/step - loss: 0.4283 - acc: 0.8625 - val_loss: 0.7616 - val_acc: 0.7685
# Epoch 105/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.4119 - acc: 0.8721 - val_loss: 0.7722 - val_acc: 0.7734
# Epoch 106/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.4317 - acc: 0.8755 - val_loss: 0.7504 - val_acc: 0.7833
# Epoch 107/300
# 5/5 [==============================] - 1s 180ms/step - loss: 0.4876 - acc: 0.8442 - val_loss: 0.7302 - val_acc: 0.7833
# Epoch 108/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.4981 - acc: 0.8468 - val_loss: 0.7151 - val_acc: 0.7980
# Epoch 109/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.4621 - acc: 0.8590 - val_loss: 0.7220 - val_acc: 0.7882
# Epoch 110/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.4052 - acc: 0.8712 - val_loss: 0.7286 - val_acc: 0.7882
# Epoch 111/300
# 5/5 [==============================] - 1s 171ms/step - loss: 0.4587 - acc: 0.8486 - val_loss: 0.7330 - val_acc: 0.7931
# Epoch 112/300
# 5/5 [==============================] - 1s 170ms/step - loss: 0.4172 - acc: 0.8660 - val_loss: 0.7598 - val_acc: 0.7931
# Epoch 113/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.4642 - acc: 0.8529 - val_loss: 0.7573 - val_acc: 0.7931
# Epoch 114/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.4537 - acc: 0.8477 - val_loss: 0.7138 - val_acc: 0.8030
# Epoch 115/300
# 5/5 [==============================] - 1s 173ms/step - loss: 0.4295 - acc: 0.8599 - val_loss: 0.6972 - val_acc: 0.8030
# Epoch 116/300
# 5/5 [==============================] - 1s 173ms/step - loss: 0.4427 - acc: 0.8616 - val_loss: 0.6966 - val_acc: 0.8030
# Epoch 117/300
# 5/5 [==============================] - 1s 177ms/step - loss: 0.4305 - acc: 0.8486 - val_loss: 0.7067 - val_acc: 0.8079
# Epoch 118/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.4061 - acc: 0.8773 - val_loss: 0.7312 - val_acc: 0.7980
# Epoch 119/300
# 5/5 [==============================] - 1s 177ms/step - loss: 0.4477 - acc: 0.8660 - val_loss: 0.7651 - val_acc: 0.7931
# Epoch 120/300
# 5/5 [==============================] - 1s 184ms/step - loss: 0.4098 - acc: 0.8729 - val_loss: 0.7619 - val_acc: 0.7980
# Epoch 121/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.3797 - acc: 0.8834 - val_loss: 0.7397 - val_acc: 0.7882
# Epoch 122/300
# 5/5 [==============================] - 1s 172ms/step - loss: 0.4396 - acc: 0.8607 - val_loss: 0.7400 - val_acc: 0.7931
# Epoch 123/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.3726 - acc: 0.8860 - val_loss: 0.7563 - val_acc: 0.7833
# Epoch 124/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.3684 - acc: 0.8956 - val_loss: 0.7924 - val_acc: 0.7734
# Epoch 125/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.4435 - acc: 0.8634 - val_loss: 0.8494 - val_acc: 0.7685
# Epoch 126/300
# 5/5 [==============================] - 1s 171ms/step - loss: 0.3662 - acc: 0.8842 - val_loss: 0.8263 - val_acc: 0.7783
# Epoch 127/300
# 5/5 [==============================] - 1s 177ms/step - loss: 0.3842 - acc: 0.8782 - val_loss: 0.8092 - val_acc: 0.7882
# Epoch 128/300
# 5/5 [==============================] - 1s 172ms/step - loss: 0.3822 - acc: 0.8921 - val_loss: 0.7780 - val_acc: 0.7882
# Epoch 129/300
# 5/5 [==============================] - 1s 171ms/step - loss: 0.4099 - acc: 0.8721 - val_loss: 0.7637 - val_acc: 0.7882
# Epoch 130/300
# 5/5 [==============================] - 1s 173ms/step - loss: 0.4208 - acc: 0.8625 - val_loss: 0.7207 - val_acc: 0.8227
# Epoch 131/300
# 5/5 [==============================] - 1s 181ms/step - loss: 0.4150 - acc: 0.8790 - val_loss: 0.7049 - val_acc: 0.7980
# Epoch 132/300
# 5/5 [==============================] - 1s 173ms/step - loss: 0.3747 - acc: 0.8816 - val_loss: 0.7278 - val_acc: 0.7882
# Epoch 133/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.3984 - acc: 0.8738 - val_loss: 0.7839 - val_acc: 0.7882
# Epoch 134/300
# 5/5 [==============================] - 1s 173ms/step - loss: 0.4283 - acc: 0.8651 - val_loss: 0.8163 - val_acc: 0.8030
# Epoch 135/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.3711 - acc: 0.8938 - val_loss: 0.8313 - val_acc: 0.7931
# Epoch 136/300
# 5/5 [==============================] - 1s 172ms/step - loss: 0.3781 - acc: 0.8851 - val_loss: 0.8110 - val_acc: 0.7980
# Epoch 137/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.3863 - acc: 0.8825 - val_loss: 0.8327 - val_acc: 0.7734
# Epoch 138/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.3867 - acc: 0.8764 - val_loss: 0.8608 - val_acc: 0.7833
# Epoch 139/300
# 5/5 [==============================] - 1s 173ms/step - loss: 0.3913 - acc: 0.8738 - val_loss: 0.8733 - val_acc: 0.7833
# Epoch 140/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.3779 - acc: 0.8721 - val_loss: 0.8508 - val_acc: 0.7783
# Epoch 141/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.3641 - acc: 0.8877 - val_loss: 0.7726 - val_acc: 0.8177
# Epoch 142/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.3738 - acc: 0.8808 - val_loss: 0.7700 - val_acc: 0.8128
# Epoch 143/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.4379 - acc: 0.8721 - val_loss: 0.7706 - val_acc: 0.8030
# Epoch 144/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.3577 - acc: 0.8790 - val_loss: 0.7456 - val_acc: 0.8079
# Epoch 145/300
# 5/5 [==============================] - 1s 177ms/step - loss: 0.3748 - acc: 0.8729 - val_loss: 0.7583 - val_acc: 0.8177
# Epoch 146/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.4270 - acc: 0.8625 - val_loss: 0.7702 - val_acc: 0.8128
# Epoch 147/300
# 5/5 [==============================] - 1s 177ms/step - loss: 0.3834 - acc: 0.8877 - val_loss: 0.7771 - val_acc: 0.8079
# Epoch 148/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.3696 - acc: 0.8842 - val_loss: 0.7550 - val_acc: 0.8128
# Epoch 149/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.3831 - acc: 0.8747 - val_loss: 0.7445 - val_acc: 0.8276
# Epoch 150/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.4424 - acc: 0.8695 - val_loss: 0.7587 - val_acc: 0.8177
# Epoch 151/300
# 5/5 [==============================] - 1s 173ms/step - loss: 0.3637 - acc: 0.8895 - val_loss: 0.7886 - val_acc: 0.7833
# Epoch 152/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.3668 - acc: 0.8860 - val_loss: 0.7780 - val_acc: 0.7931
# Epoch 153/300
# 5/5 [==============================] - 1s 172ms/step - loss: 0.4120 - acc: 0.8703 - val_loss: 0.7513 - val_acc: 0.8079
# Epoch 154/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.3671 - acc: 0.8834 - val_loss: 0.7597 - val_acc: 0.8030
# Epoch 155/300
# 5/5 [==============================] - 1s 178ms/step - loss: 0.3939 - acc: 0.8695 - val_loss: 0.7722 - val_acc: 0.8079
# Epoch 156/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.3096 - acc: 0.9051 - val_loss: 0.7845 - val_acc: 0.7980
# Epoch 157/300
# 5/5 [==============================] - 1s 171ms/step - loss: 0.3735 - acc: 0.8825 - val_loss: 0.8217 - val_acc: 0.7980
# Epoch 158/300
# 5/5 [==============================] - 1s 172ms/step - loss: 0.3672 - acc: 0.8808 - val_loss: 0.8489 - val_acc: 0.7833
# Epoch 159/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.4116 - acc: 0.8712 - val_loss: 0.8734 - val_acc: 0.7980
# Epoch 160/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.3777 - acc: 0.8947 - val_loss: 0.8701 - val_acc: 0.8030
# Epoch 161/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.3552 - acc: 0.8956 - val_loss: 0.8404 - val_acc: 0.8079
# Epoch 162/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.3567 - acc: 0.8825 - val_loss: 0.8289 - val_acc: 0.7931
# Epoch 163/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.3946 - acc: 0.8799 - val_loss: 0.8240 - val_acc: 0.7931
# Epoch 164/300
# 5/5 [==============================] - 1s 172ms/step - loss: 0.3889 - acc: 0.8773 - val_loss: 0.8352 - val_acc: 0.7833
# Epoch 165/300
# 5/5 [==============================] - 1s 177ms/step - loss: 0.3708 - acc: 0.8877 - val_loss: 0.8601 - val_acc: 0.7931
# Epoch 166/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.3832 - acc: 0.8790 - val_loss: 0.8220 - val_acc: 0.7833
# Epoch 167/300
# 5/5 [==============================] - 1s 179ms/step - loss: 0.3173 - acc: 0.9017 - val_loss: 0.7971 - val_acc: 0.7882
# Epoch 168/300
# 5/5 [==============================] - 1s 179ms/step - loss: 0.3555 - acc: 0.8877 - val_loss: 0.7993 - val_acc: 0.7931
# Epoch 169/300
# 5/5 [==============================] - 1s 177ms/step - loss: 0.3809 - acc: 0.8860 - val_loss: 0.8035 - val_acc: 0.8030
# Epoch 170/300
# 5/5 [==============================] - 1s 172ms/step - loss: 0.3527 - acc: 0.8808 - val_loss: 0.7893 - val_acc: 0.7980
# Epoch 171/300
# 5/5 [==============================] - 1s 173ms/step - loss: 0.3463 - acc: 0.8938 - val_loss: 0.8008 - val_acc: 0.8079
# Epoch 172/300
# 5/5 [==============================] - 1s 173ms/step - loss: 0.3674 - acc: 0.8869 - val_loss: 0.8254 - val_acc: 0.8030
# Epoch 173/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.3830 - acc: 0.8782 - val_loss: 0.8218 - val_acc: 0.8030
# Epoch 174/300
# 5/5 [==============================] - 1s 173ms/step - loss: 0.3584 - acc: 0.8930 - val_loss: 0.8128 - val_acc: 0.8227
# Epoch 175/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.3276 - acc: 0.8982 - val_loss: 0.8045 - val_acc: 0.8030
# Epoch 176/300
# 5/5 [==============================] - 1s 173ms/step - loss: 0.2944 - acc: 0.8999 - val_loss: 0.8210 - val_acc: 0.7882
# Epoch 177/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.3005 - acc: 0.8964 - val_loss: 0.8603 - val_acc: 0.8079
# Epoch 178/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.3355 - acc: 0.8930 - val_loss: 0.8621 - val_acc: 0.8030
# Epoch 179/300
# 5/5 [==============================] - 1s 179ms/step - loss: 0.3712 - acc: 0.8842 - val_loss: 0.8355 - val_acc: 0.7980
# Epoch 180/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.3691 - acc: 0.8964 - val_loss: 0.8026 - val_acc: 0.8030
# Epoch 181/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.3457 - acc: 0.8947 - val_loss: 0.8009 - val_acc: 0.8079
# Epoch 182/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.3832 - acc: 0.8790 - val_loss: 0.7935 - val_acc: 0.8128
# Epoch 183/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.3622 - acc: 0.8842 - val_loss: 0.7530 - val_acc: 0.8128
# Epoch 184/300
# 5/5 [==============================] - 1s 172ms/step - loss: 0.3738 - acc: 0.8860 - val_loss: 0.7389 - val_acc: 0.8128
# Epoch 185/300
# 5/5 [==============================] - 1s 170ms/step - loss: 0.3431 - acc: 0.8912 - val_loss: 0.7936 - val_acc: 0.7980
# Epoch 186/300
# 5/5 [==============================] - 1s 178ms/step - loss: 0.3591 - acc: 0.8816 - val_loss: 0.8372 - val_acc: 0.7980
# Epoch 187/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.3754 - acc: 0.8886 - val_loss: 0.8184 - val_acc: 0.7882
# Epoch 188/300
# 5/5 [==============================] - 1s 174ms/step - loss: 0.3451 - acc: 0.8903 - val_loss: 0.8057 - val_acc: 0.7931
# Epoch 189/300
# 5/5 [==============================] - 1s 176ms/step - loss: 0.3266 - acc: 0.8973 - val_loss: 0.8264 - val_acc: 0.7931
# Epoch 190/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.3625 - acc: 0.8842 - val_loss: 0.8406 - val_acc: 0.7882
# Epoch 191/300
# 5/5 [==============================] - 1s 179ms/step - loss: 0.2829 - acc: 0.9104 - val_loss: 0.8277 - val_acc: 0.8128
# Epoch 192/300
# 5/5 [==============================] - 1s 172ms/step - loss: 0.3344 - acc: 0.8973 - val_loss: 0.8153 - val_acc: 0.8030
# Epoch 193/300
# 5/5 [==============================] - 1s 179ms/step - loss: 0.3255 - acc: 0.9060 - val_loss: 0.8609 - val_acc: 0.7882
# Epoch 194/300
# 5/5 [==============================] - 1s 172ms/step - loss: 0.3342 - acc: 0.8895 - val_loss: 0.8849 - val_acc: 0.7882
# Epoch 195/300
# 5/5 [==============================] - 1s 178ms/step - loss: 0.3567 - acc: 0.8903 - val_loss: 0.8430 - val_acc: 0.8030
# Epoch 196/300
# 5/5 [==============================] - 1s 175ms/step - loss: 0.3488 - acc: 0.8816 - val_loss: 0.8692 - val_acc: 0.7931
# Epoch 197/300
# 5/5 [==============================] - 1s 173ms/step - loss: 0.3697 - acc: 0.8921 - val_loss: 0.8509 - val_acc: 0.7931
# Epoch 198/300
# 5/5 [==============================] - 1s 170ms/step - loss: 0.3121 - acc: 0.8947 - val_loss: 0.8232 - val_acc: 0.7980
# Epoch 199/300
# 5/5 [==============================] - 1s 178ms/step - loss: 0.3999 - acc: 0.8773 - val_loss: 0.8148 - val_acc: 0.8079

# %%
display_learning_curves(history)

# %%
x_test = test_data.paper_id.to_numpy()
_, test_accuracy = gnn_model.evaluate(x=x_test, y=y_test, verbose=0)
print(f"Test accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# Test accuracy: 80.9%

# %%
# First we add the N new_instances as nodes to the graph
# by appending the new_instance to node_features.
num_nodes = node_features.shape[0]
new_node_features = np.concatenate([node_features, new_instances])
# Second we add the M edges (citations) from each new node to a set
# of existing nodes in a particular subject
new_node_indices = [i + num_nodes for i in range(num_classes)]
new_citations = []
for subject_idx, group in papers.groupby("subject"):
    subject_papers = list(group.paper_id)
    # Select random x papers specific subject.
    selected_paper_indices1 = np.random.choice(subject_papers, 5)
    # Select random y papers from any subject (where y < x).
    selected_paper_indices2 = np.random.choice(list(papers.paper_id), 2)
    # Merge the selected paper indices.
    selected_paper_indices = np.concatenate(
        [selected_paper_indices1, selected_paper_indices2], axis=0
    )
    # Create edges between a citing paper idx and the selected cited papers.
    citing_paper_indx = new_node_indices[subject_idx]
    for cited_paper_idx in selected_paper_indices:
        new_citations.append([citing_paper_indx, cited_paper_idx])

new_citations = np.array(new_citations).T
new_edges = np.concatenate([edges, new_citations], axis=1)

# %%
print("Original node_features shape:", gnn_model.node_features.shape)
print("Original edges shape:", gnn_model.edges.shape)
gnn_model.node_features = new_node_features
gnn_model.edges = new_edges
gnn_model.edge_weights = tf.ones(shape=new_edges.shape[1])
print("New node_features shape:", gnn_model.node_features.shape)
print("New edges shape:", gnn_model.edges.shape)

logits = gnn_model.predict(tf.convert_to_tensor(new_node_indices))
probabilities = keras.activations.softmax(tf.convert_to_tensor(logits)).numpy()
display_class_probabilities(probabilities)
# Out:
# Original node_features shape: (2708, 1433)
# Original edges shape: (2, 5429)
# New node_features shape: (2715, 1433)
# New edges shape: (2, 5478)
# Instance 1:
# - Case_Based: 3.68%
# - Genetic_Algorithms: 11.31%
# - Neural_Networks: 2.6%
# - Probabilistic_Methods: 0.91%
# - Reinforcement_Learning: 70.27%
# - Rule_Learning: 7.34%
# - Theory: 3.89%
# Instance 2:
# - Case_Based: 0.04%
# - Genetic_Algorithms: 0.04%
# - Neural_Networks: 0.48%
# - Probabilistic_Methods: 0.09%
# - Reinforcement_Learning: 0.03%
# - Rule_Learning: 0.05%
# - Theory: 99.28%
# Instance 3:
# - Case_Based: 0.12%
# - Genetic_Algorithms: 1.25%
# - Neural_Networks: 84.29%
# - Probabilistic_Methods: 12.12%
# - Reinforcement_Learning: 0.62%
# - Rule_Learning: 0.05%
# - Theory: 1.54%
# Instance 4:
# - Case_Based: 0.01%
# - Genetic_Algorithms: 0.02%
# - Neural_Networks: 0.88%
# - Probabilistic_Methods: 98.58%
# - Reinforcement_Learning: 0.02%
# - Rule_Learning: 0.0%
# - Theory: 0.49%
# Instance 5:
# - Case_Based: 7.74%
# - Genetic_Algorithms: 6.36%
# - Neural_Networks: 2.58%
# - Probabilistic_Methods: 0.56%
# - Reinforcement_Learning: 47.15%
# - Rule_Learning: 27.65%
# - Theory: 7.96%
# Instance 6:
# - Case_Based: 0.26%
# - Genetic_Algorithms: 0.35%
# - Neural_Networks: 8.11%
# - Probabilistic_Methods: 88.78%
# - Reinforcement_Learning: 0.44%
# - Rule_Learning: 0.13%
# - Theory: 1.93%
# Instance 7:
# - Case_Based: 0.65%
# - Genetic_Algorithms: 57.02%
# - Neural_Networks: 4.23%
# - Probabilistic_Methods: 0.19%
# - Reinforcement_Learning: 37.24%
# - Rule_Learning: 0.16%
# - Theory: 0.52%

# %%
# bag-of-wordsで73%
# 引用関係を考慮して80%
# ある論文がどの分野の論文なのかを決めるに当たり，
# 中身の単語のほうが，引用関係より重要で，それだけを用いてもそれなりに当たる．
# 一方で，引用関係を追加するとちょっとだけ当たる精度がマシになる．
